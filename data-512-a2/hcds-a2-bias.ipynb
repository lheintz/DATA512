# %% [markdown]
# # <center> HW Assignment 2</center>
# <center> Data Curation </center>
# <center> Lauren Heintz </center>
# <center> DATA 512, Fall 2019 </center>
# <center> Due 10/17/19 </center>

# %% [markdown]
# ## 0. The Goal
# The goal of this analysis is to observe how the coverage of politicians on Wikipedia and the quality of articles about politicians varies between countries. The analysis will focus on tables that show:
#
# __The countries with the greatest and least coverage of politicians on Wikipedia compared to their population.
# The countries with the highest and lowest proportion of high quality articles about politicians.
# A ranking of geographic regions by articles-per-person and proportion of high quality articles.__

# %% [markdown]
# ## I. Data Acquisition
# Two types of data were used for this analysis. The Wikipedia politicians by country dataset and the world population data set.
# [Politicians by country data set found here](https://figshare.com/articles/Untitled_Item/5513449).
# [World population dataset found here](https://www.prb.org/international/indicator/population/table/).
#
# CSVs of both were saved locally and then loaded in the steps below.

# %%
import pandas as pd
import numpy as np
import requests
import json
from pandas.io.json import json_normalize  

# %cd ~/Docs/MSDS/Fa2019/data512/data-512-a2
# Out:
# /Users/laurenheintz/Docs/MSDS/Fa2019/data512/data-512-a2

# %%
polData = pd.read_csv('data_raw/page_data.csv', sep=',', header=0) # polData is politican by country data
popData = pd.read_csv('data_raw/WPDS_2018_data.csv', sep=',', header=0) # popData is population by country data
polData.head(5)
# Out:
#                                  page   country     rev_id
# 0  Template:ZambiaProvincialMinisters    Zambia  235107991
# 1                      Bir I of Kanem      Chad  355319463
# 2   Template:Zimbabwe-politician-stub  Zimbabwe  391862046
# 3     Template:Uganda-politician-stub    Uganda  391862070
# 4    Template:Namibia-politician-stub   Namibia  391862409

# %%
popData.head(5)
# Out:
#   Geography Population mid-2018 (millions)
# 0    AFRICA                          1,284
# 1   Algeria                           42.7
# 2     Egypt                             97
# 3     Libya                            6.5
# 4   Morocco                           35.2

# %% [markdown]
# ## II. Data Processing
# The following section outlines the data processing that was done to prepare for this analysis.
#
# ### Politician Pages By Country
# First, we will check to see if there are any missing values. If there are, we will replace them with Nan.
# This data set contains rows which start with the word "template" which are not actually pages, and must be removed from the dataset.

# %%
# Look for missing or null & fill with zero
if (polData.isnull().values.any()):
    polData = polData.fillna(0)

# Filter out data containing template
polData = polData[~polData.page.str.contains("Template")]
polData = polData.sort_values(by=['country'])
polData = polData.reset_index(drop=True)
polData.head(10)
# Out:
#                page   country     rev_id
# 0        Raul Eshba  Abkhazia  789039267
# 1     Zakan Jugelia  Abkhazia  786203824
# 2       Zurab Achba  Abkhazia  721094337
# 3    Sumbat Saakian  Abkhazia  755193428
# 4  Gennadi Berulava  Abkhazia  805063877
# 5       Efrem Eshba  Abkhazia  798644673
# 6      Yuri Voronov  Abkhazia  803018106
# 7      Zaur Avidzba  Abkhazia  694519009
# 8   Bagrat Shinkuba  Abkhazia  789818648
# 9     Nestor Lakoba  Abkhazia  805967589

# %% [markdown]
# ### Population By Country
# First, we will check to see if there are any missing values. If there are, we will replace them with Nan.
# This data set contains entries in the country column which are not countries, but regions. These are in all caps. These will not have match data in the pages data set. So for now, we will filter out this data and save it offline to a csv so we can analyze it later.

# %%
# Look for missing or null & fill with zero
if (popData.isnull().values.any()):
    popData = popData.fillna(0)

# Locate rows with ALL CAPS, save this regional roll up data elsewhere
popData[popData.Geography.str.isupper()].to_csv('data_clean/GeographyRollUp.csv', index=False)

# Filter out the non-country data (all caps)
popData = popData[~popData.Geography.str.isupper()]
popData.head(5)
# Out:
#   Geography Population mid-2018 (millions)
# 1   Algeria                           42.7
# 2     Egypt                             97
# 3     Libya                            6.5
# 4   Morocco                           35.2
# 5     Sudan                           41.7

# %%
# Rename Geography to country, sort by country, re index
popData = popData.rename(columns={'Geography': 'country', 'Population mid-2018 (millions)':'population'})

# %%
popData = popData.sort_values(by=['country'])
popData = popData.reset_index(drop=True)
popData.head(10)
# Out:
#                country population
# 0          Afghanistan       36.5
# 1              Albania        2.9
# 2              Algeria       42.7
# 3              Andorra       0.08
# 4               Angola       30.4
# 5  Antigua and Barbuda        0.1
# 6            Argentina       44.5
# 7              Armenia          3
# 8            Australia       24.1
# 9              Austria        8.8

# %% [markdown]
# ### Aqcuire ORES Scores from ORES Rest API
# Explanation of ORES score and API and API documentation.
# Must be joined to pages data.

# %% [markdown]
# Turn the column of revision IDs in the pandas data frame in to a list

# %%
# Turn the column of revision IDs in the pandas data frame in to a list
rev_list = polData['rev_id'].tolist()

# %% [markdown]
# Now we use the code below provided by Jonathan to access the API call.

# %%
headers = {'User-Agent' : 'https://github.com/lheintz', 'From' : 'heintzl@uw.edu'}

# %%
def get_ores_data(revision_ids, headers):
    
    # Define the endpoint
    endpoint = 'https://ores.wikimedia.org/v3/scores/{project}/?models={model}&revids={revids}'
    
    # Specify the parameters - smushing all the revision IDs together separated by | marks.
    # Yes, 'smush' is a technical term, trust me I'm a scientist.
    # What do you mean "but people trusting scientists regularly goes horribly wrong" who taught you tha- oh.  
    params = {'project' : 'enwiki',
              'model'   : 'wp10',
              'revids'  : '|'.join(str(x) for x in revision_ids)
              }
    api_call = requests.get(endpoint.format(**params))
    response = api_call.json()
#     print(json.dumps(response, indent=4, sort_keys=True))
    return response

# %% [markdown]
# Lets create some code that interprets the json.

# %%
import os
from pprint import pprint
import pandas as pandas
from json import load

class ModelScore:
    __slots__ = ("identifier", "prediction", "probabilities", "stub")
    # slots used to choose which values will be a part of the object 

    def __init__(
        self, identifier: int = None, prediction: str = None, probabilities: dict = None
    ):
        self.identifier = identifier
        self.prediction = prediction
        self.probabilities = probabilities
        self.stub = self.probabilities.get("Stub")

    # Method to print outputs nicely if desired for debugging
    def __repr__(self):
        string = "{"
        for index, key in enumerate(self.__slots__):
            string += "{"
            string += f"{key}: {str(getattr(self, key, None))}"
            if index < len(self.__slots__) - 1:
                string += "}, "
            else:
                string += "}"
        return string

class JSONParser:
    @staticmethod
    def parse(path_to_json_file):
        """ 
        The sub-function to turn the json file of the raw
        outputs from the ORES API call in to a dictionary. 
  
        Parameters: 
            path_to_json_file (string): The path to the raw json file returned from the API call
          
        Returns: 
            json_as_dictionary (dictionary): A python dictionary object of the original json
        """

        # Returns json as a dictionary

        with open(path_to_json_file) as json_file:
            json_as_dictionary = load(json_file)
        return json_as_dictionary

def json_path_to_dataframe(path_to_json_file):
    """ 
        The function to turn the json file of the raw
        outputs from the ORES API call in to a clean df
        in the format that we want. 
  
        Parameters: 
            path_to_json_file (string): The path to the raw json file returned from the API call
          
        Returns: 
            model_scores (dataframe): Returns the predicted scores from the model for each Revision Id queried
    """
    # Use json parser class to parse json in to a dictionary

    json_parser = JSONParser()
    json_as_dictionary = json_parser.parse(path_to_json_file)
    
    all_scores = json_as_dictionary.get("enwiki").get("scores")
    
    all_score_ids_mapped_to_info = {}
    for score in all_scores:
        all_score_ids_mapped_to_info[score] = (
            all_scores.get(score).get("wp10").get("score")
        )
    
    # Use model score class to choose values we want to add to a df

    model_scores = []
    for key, value in all_score_ids_mapped_to_info.items():
        try:
            model_scores.append([key, value.get("prediction")])
        except AttributeError:
            model_scores.append([key, 0])
    
    return pandas.DataFrame(model_scores)

# %%
len(rev_list)
# Out:
# 46701

# %%
len(set(rev_list))
# Out:
# 46701

# %%
df_clean = pd.DataFrame([])

for i in range(467):
    df = get_ores_data(rev_list[i:i+100], headers)
    
    with open('data_raw/ores-json-data-raw.json', 'w') as json_file:
        json.dump(df, json_file)
        
    df = json_path_to_dataframe('data_raw/ores-json-data-raw.json')
    df_clean = df_clean.append(df)

# %%
df_clean[0].nunique()
# Out:
# 566

# %%
df_clean
# Out:
#             0      1
# 0   694519009  Start
# 1   704938340  Start
# 2   706112927   Stub
# 3   713113246   Stub
# 4   715926834   Stub
# 5   715926905   Stub
# 6   718250607   Stub
# 7   718362010  Start
# 8   718362588   Stub
# 9   718364221   Stub
# 10  718382045   Stub
# 11  718383950   Stub
# 12  718384584  Start
# 13  718384771   Stub
# 14  720586068   Stub
# 15  721094337   Stub
# 16  723481980   Stub
# 17  723709911   Stub
# 18  723736482   Stub
# 19  727899635   Stub
# 20  730949872   Stub
# 21  745190115   Stub
# 22  747783201   Stub
# 23  750347412  Start
# 24  750535372   Stub
# 25  750544170   Stub
# 26  750549549   Stub
# 27  750561890  Start
# 28  751150581   Stub
# 29  751959879   Stub
# ..        ...    ...
# 70  789270784   Stub
# 71  789270787   Stub
# 72  789272024      C
# 73  790232486   Stub
# 74  790240137  Start
# 75  790378063   Stub
# 76  791693230      C
# 77  797474291   Stub
# 78  797490997   Stub
# 79  798552371      C
# 80  799644994      C
# 81  799802367   Stub
# 82  801196501  Start
# 83  802161072  Start
# 84  802276196      C
# 85  802380908  Start
# 86  802437768  Start
# 87  802437777      C
# 88  802437821  Start
# 89  802437823  Start
# 90  802437825  Start
# 91  802437830  Start
# 92  802437849   Stub
# 93  802437981   Stub
# 94  803638786  Start
# 95  804514843  Start
# 96  804882538      C
# 97  805412290   Stub
# 98  805535874      C
# 99  807458594  Start
#
# [46700 rows x 2 columns]

# %%
df = get_ores_data(rev_list[46700:46701], headers)
    
with open('data_raw/ores-json-data-raw.json', 'w') as json_file:
    json.dump(df, json_file)
        
df = json_path_to_dataframe('data_raw/ores-json-data-raw.json')
df_clean = df_clean.append(df)

# %%
df_clean = df_clean.rename(columns={0:'rev_id', 1:'prediction'})
df_clean
# Out:
#        rev_id prediction
# 0   694519009      Start
# 1   704938340      Start
# 2   706112927       Stub
# 3   713113246       Stub
# 4   715926834       Stub
# 5   715926905       Stub
# 6   718250607       Stub
# 7   718362010      Start
# 8   718362588       Stub
# 9   718364221       Stub
# 10  718382045       Stub
# 11  718383950       Stub
# 12  718384584      Start
# 13  718384771       Stub
# 14  720586068       Stub
# 15  721094337       Stub
# 16  723481980       Stub
# 17  723709911       Stub
# 18  723736482       Stub
# 19  727899635       Stub
# 20  730949872       Stub
# 21  745190115       Stub
# 22  747783201       Stub
# 23  750347412      Start
# 24  750535372       Stub
# 25  750544170       Stub
# 26  750549549       Stub
# 27  750561890      Start
# 28  751150581       Stub
# 29  751959879       Stub
# ..        ...        ...
# 71  789270787       Stub
# 72  789272024          C
# 73  790232486       Stub
# 74  790240137      Start
# 75  790378063       Stub
# 76  791693230          C
# 77  797474291       Stub
# 78  797490997       Stub
# 79  798552371          C
# 80  799644994          C
# 81  799802367       Stub
# 82  801196501      Start
# 83  802161072      Start
# 84  802276196          C
# 85  802380908      Start
# 86  802437768      Start
# 87  802437777          C
# 88  802437821      Start
# 89  802437823      Start
# 90  802437825      Start
# 91  802437830      Start
# 92  802437849       Stub
# 93  802437981       Stub
# 94  803638786      Start
# 95  804514843      Start
# 96  804882538          C
# 97  805412290       Stub
# 98  805535874          C
# 99  807458594      Start
# 0   713121927       Stub
#
# [46701 rows x 2 columns]

# %% [markdown]
# We have now parsed all the predictions from the jsons and saved this as a PDF. In this CSV, there are some 0 values which signify that no value was found to be returned by the API.

# %%
df_clean.to_csv('data_raw/pred_scores.csv', index=False)

# %%
df_clean.reset_index(drop = True)
df_clean.head(10)
# Out:
#       rev_id prediction
# 0  694519009      Start
# 1  704938340      Start
# 2  706112927       Stub
# 3  713113246       Stub
# 4  715926834       Stub
# 5  715926905       Stub
# 6  718250607       Stub
# 7  718362010      Start
# 8  718362588       Stub
# 9  718364221       Stub

# %% [markdown]
# Now to clean things up, we drop the items that had a zero for the prediction and then save this file to our clean data folder. Now we should only have rev IDs that have non-zero predictions.

# %%
# Filter out the data that did not have ORES prediction scores available and save to CSV

missing = df_clean[(df_clean[['prediction']] == 0).any(axis=1)]
missing = missing.drop(columns=["prediction"])
missing.to_csv('results/ores-no-score.csv', index = False)

df_clean = df_clean[~(df_clean[['prediction']] == 0).any(axis=1)]
df_clean.to_csv('data_clean/pred_scores.csv', index=False)

# %% [markdown]
# I saved these results in a CSV so that I did not have to run the API call & do data cleaning again. Now I reloaded this save CSV from above and will join it to the politican pages dataset it came from.

# %%
predictions = pd.read_csv('data_clean/pred_scores.csv')
predictions.head(5)
# Out:
#       rev_id prediction
# 0  694519009      Start
# 1  704938340      Start
# 2  706112927       Stub
# 3  713113246       Stub
# 4  715926834       Stub

# %% [markdown]
# Lets check out the data type on the two columns we would like to merge on: revision ID.

# %%
predictions.dtypes
# Out:
# rev_id         int64
# prediction    object
# dtype: object

# %%
polData.dtypes
# Out:
# page       object
# country    object
# rev_id      int64
# dtype: object

# %%
predictions['rev_id'].nunique()
# Out:
# 565

# %%
polDataPredictions
# Out:
#                               page   country     rev_id prediction
# 0                       Raul Eshba  Abkhazia  789039267       Stub
# 1                    Zakan Jugelia  Abkhazia  786203824      Start
# 2                    Zakan Jugelia  Abkhazia  786203824      Start
# 3                      Zurab Achba  Abkhazia  721094337       Stub
# 4                      Zurab Achba  Abkhazia  721094337       Stub
# 5                      Zurab Achba  Abkhazia  721094337       Stub
# 6                   Sumbat Saakian  Abkhazia  755193428       Stub
# 7                   Sumbat Saakian  Abkhazia  755193428       Stub
# 8                   Sumbat Saakian  Abkhazia  755193428       Stub
# 9                   Sumbat Saakian  Abkhazia  755193428       Stub
# 10                Gennadi Berulava  Abkhazia  805063877       Stub
# 11                Gennadi Berulava  Abkhazia  805063877       Stub
# 12                Gennadi Berulava  Abkhazia  805063877       Stub
# 13                Gennadi Berulava  Abkhazia  805063877       Stub
# 14                Gennadi Berulava  Abkhazia  805063877       Stub
# 15                     Efrem Eshba  Abkhazia  798644673       Stub
# 16                     Efrem Eshba  Abkhazia  798644673       Stub
# 17                     Efrem Eshba  Abkhazia  798644673       Stub
# 18                     Efrem Eshba  Abkhazia  798644673       Stub
# 19                     Efrem Eshba  Abkhazia  798644673       Stub
# 20                     Efrem Eshba  Abkhazia  798644673       Stub
# 21                    Yuri Voronov  Abkhazia  803018106       Stub
# 22                    Yuri Voronov  Abkhazia  803018106       Stub
# 23                    Yuri Voronov  Abkhazia  803018106       Stub
# 24                    Yuri Voronov  Abkhazia  803018106       Stub
# 25                    Yuri Voronov  Abkhazia  803018106       Stub
# 26                    Yuri Voronov  Abkhazia  803018106       Stub
# 27                    Yuri Voronov  Abkhazia  803018106       Stub
# 28                    Zaur Avidzba  Abkhazia  694519009      Start
# 29                    Zaur Avidzba  Abkhazia  694519009      Start
# ...                            ...       ...        ...        ...
# 92682                 Edgar Tekere  Zimbabwe  798106157        NaN
# 92683         Christopher Kuruneri  Zimbabwe  789427326        NaN
# 92684  Felix Magalela Mafa Sibanda  Zimbabwe  769519957        NaN
# 92685             Ignatious Chombo  Zimbabwe  806656210        NaN
# 92686                 Rugare Gumbo  Zimbabwe  749496266        NaN
# 92687              Fletcher Dulini  Zimbabwe  669981316        NaN
# 92688               Solomon Mujuru  Zimbabwe  789898624        NaN
# 92689             Maurice Nyagumbo  Zimbabwe  764826793        NaN
# 92690             Sithembiso Nyoni  Zimbabwe  757617613        NaN
# 92691                 Ronald Penza  Zimbabwe  789948565        NaN
# 92692             Simon Khaya-Moyo  Zimbabwe  730764918        NaN
# 92693                Moven Mahachi  Zimbabwe  783298283        NaN
# 92694           Henry Dzinotyiweyi  Zimbabwe  715867004        NaN
# 92695               Diana Mitchell  Zimbabwe  764299725        NaN
# 92696            Promise Mkwananzi  Zimbabwe  803579259        NaN
# 92697                  Joseph Made  Zimbabwe  789965571        NaN
# 92698               Margaret Dongo  Zimbabwe  783419906        NaN
# 92699                  Joel Gabuza  Zimbabwe  776840034        NaN
# 92700          Misheck Kagurabadza  Zimbabwe  720008799        NaN
# 92701                 Jevan Maseko  Zimbabwe  736911246        NaN
# 92702             Arthur Mutambara  Zimbabwe  797932659        NaN
# 92703                Sekai Holland  Zimbabwe  783637102        NaN
# 92704              Rekayi Tangwena  Zimbabwe  716669163        NaN
# 92705            Alfred Makwarimba  Zimbabwe  801370822        NaN
# 92706            Blessing Chebundo  Zimbabwe  791690130        NaN
# 92707            Munyaradzi Gwisai  Zimbabwe  755337199        NaN
# 92708        Alfred Nikita Mangena  Zimbabwe  712004487        NaN
# 92709             Lovemore Matombo  Zimbabwe  711958194        NaN
# 92710               Edward Raradza  Zimbabwe  716017725        NaN
# 92711                 Simbi Mubako  Zimbabwe  713121927       Stub
#
# [92712 rows x 4 columns]

# %%
# Merge to pol data by rev_id
# polData['rev_id'] = polData['rev_id'].astype(int)
# df_clean['rev_id'] = df_clean['rev_id'].astype(int)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_clean
# Out:
#        rev_id prediction
# 0   694519009      Start
# 1   704938340      Start
# 2   706112927       Stub
# 3   713113246       Stub
# 4   715926834       Stub
# 5   715926905       Stub
# 6   718250607       Stub
# 7   718362010      Start
# 8   718362588       Stub
# 9   718364221       Stub
# 10  718382045       Stub
# 11  718383950       Stub
# 12  718384584      Start
# 13  718384771       Stub
# 14  720586068       Stub
# 15  721094337       Stub
# 16  723481980       Stub
# 17  723709911       Stub
# 18  723736482       Stub
# 19  727899635       Stub
# 20  730949872       Stub
# 21  745190115       Stub
# 22  747783201       Stub
# 23  750347412      Start
# 24  750535372       Stub
# 25  750544170       Stub
# 26  750549549       Stub
# 27  750561890      Start
# 28  751150581       Stub
# 29  751959879       Stub
# ..        ...        ...
# 71  789270787       Stub
# 72  789272024          C
# 73  790232486       Stub
# 74  790240137      Start
# 75  790378063       Stub
# 76  791693230          C
# 77  797474291       Stub
# 78  797490997       Stub
# 79  798552371          C
# 80  799644994          C
# 81  799802367       Stub
# 82  801196501      Start
# 83  802161072      Start
# 84  802276196          C
# 85  802380908      Start
# 86  802437768      Start
# 87  802437777          C
# 88  802437821      Start
# 89  802437823      Start
# 90  802437825      Start
# 91  802437830      Start
# 92  802437849       Stub
# 93  802437981       Stub
# 94  803638786      Start
# 95  804514843      Start
# 96  804882538          C
# 97  805412290       Stub
# 98  805535874          C
# 99  807458594      Start
# 0   713121927       Stub
#
# [46576 rows x 2 columns]

# %%
# %cd ~/Docs/MSDS/Fa2019/
pred = pd.read_csv('prediction.csv')
pred.head(5)
# Out:
# /Users/laurenheintz/Docs/MSDS/Fa2019
#       rev_id prediction
# 0  355319463       Stub
# 1  393276188       Stub
# 2  393822005       Stub
# 3  395521877       Stub
# 4  395526568       Stub

# %%
# Merge to pol data by rev_id
polDataScore = pd.merge(polData, pred, how = "outer", on= "rev_id")
polDataScore = polDataScore[~polDataScore["prediction"].str.contains("Rev")]
polDataScore = polDataScore[~polDataScore['prediction'].str.contains("Text")]
polDataScore = polDataScore.sort_values(by=['country']).reset_index(drop=True)

# %%
polDataScore
# Out:
#                                                     page      country  \
# 0                                             Raul Eshba     Abkhazia
# 1                                        Zhiuli Shartava     Abkhazia
# 2                                          Zaur Ardzinba     Abkhazia
# 3                                             Garri Aiba     Abkhazia
# 4                                       Guram Gabiskiria     Abkhazia
# 5                                        Shota Shamatava     Abkhazia
# 6                                          Nestor Lakoba     Abkhazia
# 7                                        Bagrat Shinkuba     Abkhazia
# 8                                          Samson Chanba     Abkhazia
# 9                                           Yuri Voronov     Abkhazia
# 10                                           Efrem Eshba     Abkhazia
# 11                                      Gennadi Berulava     Abkhazia
# 12                                        Sumbat Saakian     Abkhazia
# 13                                           Zurab Achba     Abkhazia
# 14                                         Zakan Jugelia     Abkhazia
# 15                                          Zaur Avidzba     Abkhazia
# 16                           Abdul Qadir (Afghan leader)  Afghanistan
# 17                                     Rouh Gul Khairzad  Afghanistan
# 18                                   Baz Mohammad Ahmadi  Afghanistan
# 19                                  Mohammad Ishaq Aloko  Afghanistan
# 20                                   Mohammed Zia Salehi  Afghanistan
# 21                                Mohammad Shafiq Hamdam  Afghanistan
# 22                                        Mohammed Rafie  Afghanistan
# 23                                         Zefnoon Safai  Afghanistan
# 24                                           Hanifa Safi  Afghanistan
# 25                           Sayyed Mohammad Eqbal Munib  Afghanistan
# 26                                 Abdul Karim Mustaghni  Afghanistan
# 27                                Mohammad Shakir Kargar  Afghanistan
# 28                                          Fawzia Koofi  Afghanistan
# 29                                Abdul Hadi Arghandiwal  Afghanistan
# ...                                                  ...          ...
# 46516                                     Lazarus Dokora     Zimbabwe
# 46517                                      Enos Mdlongwa     Zimbabwe
# 46518                                 Josiah Zion Gumede     Zimbabwe
# 46519                                   Emmanuel Chiroto     Zimbabwe
# 46520                                   Chenjerai Hunzvi     Zimbabwe
# 46521                                       Grace Mugabe     Zimbabwe
# 46522                                   Learnmore Jongwe     Zimbabwe
# 46523                                      Naison Ndlovu     Zimbabwe
# 46524                                   Lovemore Madhuku     Zimbabwe
# 46525                                    George Charamba     Zimbabwe
# 46526  List of candidates in the Zimbabwean parliamen...     Zimbabwe
# 46527                                       Martin Dinha     Zimbabwe
# 46528                                  Reuben Marumahoko     Zimbabwe
# 46529                                     Fidelis Mhashu     Zimbabwe
# 46530                                 Nicholas Kiti kiti     Zimbabwe
# 46531                                          Fay Chung     Zimbabwe
# 46532                                    George Nyandoro     Zimbabwe
# 46533                                   Nyasha Chikwinya     Zimbabwe
# 46534                                       Janet Banana     Zimbabwe
# 46535                                    Naomi Nhiwatiwa     Zimbabwe
# 46536                           Edward Chindori-Chininga     Zimbabwe
# 46537                                        David Butau     Zimbabwe
# 46538                                     Theresa Makoni     Zimbabwe
# 46539                                       Lutho Tapela     Zimbabwe
# 46540                             First Lady of Zimbabwe     Zimbabwe
# 46541                                  Thompson Samkange     Zimbabwe
# 46542                                    Trudy Stevenson     Zimbabwe
# 46543                                      Elton Mangoma     Zimbabwe
# 46544                                  Muchadeyi Masunda     Zimbabwe
# 46545                                       Simbi Mubako     Zimbabwe
#
#           rev_id prediction
# 0      789039267       Stub
# 1      802029007      Start
# 2      704938340      Start
# 3      799618550      Start
# 4      805775169      Start
# 5      723736482       Stub
# 6      805967589         GA
# 7      789818648      Start
# 8      789818730      Start
# 9      803018106       Stub
# 10     798644673       Stub
# 11     805063877       Stub
# 12     755193428       Stub
# 13     721094337       Stub
# 14     786203824      Start
# 15     694519009      Start
# 16     798059926          C
# 17     788030456       Stub
# 18     782271549       Stub
# 19     770905450      Start
# 20     799023841       Stub
# 21     799023086          C
# 22     776933374       Stub
# 23     716814855       Stub
# 24     754262111       Stub
# 25     782271570       Stub
# 26     795022269       Stub
# 27     783321773       Stub
# 28     806916131          C
# 29     739136660       Stub
# ...          ...        ...
# 46516  780062778       Stub
# 46517  787854640       Stub
# 46518  765095810      Start
# 46519  714535045       Stub
# 46520  797225827          C
# 46521  807337237         GA
# 46522  804844902      Start
# 46523  787854175       Stub
# 46524  804895632          C
# 46525  793738070      Start
# 46526  735498335      Start
# 46527  738992918       Stub
# 46528  726688205       Stub
# 46529  803084855       Stub
# 46530  713308132       Stub
# 46531  800705666          B
# 46532  750224976      Start
# 46533  742899761      Start
# 46534  777849777       Stub
# 46535  743971092      Start
# 46536  797414978      Start
# 46537  714967769       Stub
# 46538  790423262       Stub
# 46539  782607746       Stub
# 46540  796477244       Stub
# 46541  715131189       Stub
# 46542  776943338      Start
# 46543  801497420      Start
# 46544  714706533          C
# 46545  713121927       Stub
#
# [46546 rows x 4 columns]

# %% [markdown]
# Remove or documents entries for which no ORES prediction was available.

# %% [markdown]
# ### Join Pages and Population Data
# The data on politician pages and population must now be joined. The data set will not match up exactly. Countries which are missing either Pages or Population data will be excluded in our analysis dataset, but saved to `wp_wpds_countries-no_match.csv`.
#
# The complete data set with no missing values will be saved as `wp_wpds_politicians_by_country.csv`.

# %%
# Merge columns by the country name, do an outer join
allData = pd.merge(popData, polDataScore, how = "outer", on = "country")

# Clean data by sorting, filling NAs with zero, and reseting the index
allData = allData.sort_values(by=['country']).fillna(0).reset_index(drop=True)

# %%
allData
# Out:
#            country population                                          page  \
# 0         Abkhazia          0                                    Raul Eshba
# 1         Abkhazia          0                               Zhiuli Shartava
# 2         Abkhazia          0                                  Zaur Avidzba
# 3         Abkhazia          0                                 Zakan Jugelia
# 4         Abkhazia          0                                   Zurab Achba
# 5         Abkhazia          0                              Gennadi Berulava
# 6         Abkhazia          0                                   Efrem Eshba
# 7         Abkhazia          0                                  Yuri Voronov
# 8         Abkhazia          0                                Sumbat Saakian
# 9         Abkhazia          0                               Bagrat Shinkuba
# 10        Abkhazia          0                                 Nestor Lakoba
# 11        Abkhazia          0                               Shota Shamatava
# 12        Abkhazia          0                              Guram Gabiskiria
# 13        Abkhazia          0                                    Garri Aiba
# 14        Abkhazia          0                                 Zaur Ardzinba
# 15        Abkhazia          0                                 Samson Chanba
# 16     Afghanistan       36.5                              Nur ul-Haq Ulumi
# 17     Afghanistan       36.5                           Al-Haj Suliman Yari
# 18     Afghanistan       36.5                         Ghulam Qawis Abubaker
# 19     Afghanistan       36.5                         Mohammad Fahim Dashty
# 20     Afghanistan       36.5                                 Seema Jowenda
# 21     Afghanistan       36.5      Dost Mohammad Khan (Emir of Afghanistan)
# 22     Afghanistan       36.5                        Hashmat Ghani Ahmadzai
# 23     Afghanistan       36.5                                 Humayun Azizi
# 24     Afghanistan       36.5                             Abdul Ahad Karzai
# 25     Afghanistan       36.5                             Abdullah Abdullah
# 26     Afghanistan       36.5                      Amir Muhammad Akhundzada
# 27     Afghanistan       36.5                                 Mohammad Aman
# 28     Afghanistan       36.5                        Haji Mohammad Chamkani
# 29     Afghanistan       36.5                                Amrullah Saleh
# ...            ...        ...                                           ...
# 46537     Zimbabwe         14                                 Michael Bimha
# 46538     Zimbabwe         14                                  Kembo Mohadi
# 46539     Zimbabwe         14                               Walter Chidakwa
# 46540     Zimbabwe         14                             Ambrose Mutinhiri
# 46541     Zimbabwe         14                                 Sesel Zvidzai
# 46542     Zimbabwe         14                               Fletcher Dulini
# 46543     Zimbabwe         14                            Henry Dzinotyiweyi
# 46544     Zimbabwe         14                             Guy Clutton-Brock
# 46545     Zimbabwe         14                                Edna Madzongwe
# 46546     Zimbabwe         14                             Promise Mkwananzi
# 46547     Zimbabwe         14                                   Joseph Made
# 46548     Zimbabwe         14                                Margaret Dongo
# 46549     Zimbabwe         14                                   Joel Gabuza
# 46550     Zimbabwe         14                           Misheck Kagurabadza
# 46551     Zimbabwe         14                              Arthur Mutambara
# 46552     Zimbabwe         14                                 Sekai Holland
# 46553     Zimbabwe         14                               Rekayi Tangwena
# 46554     Zimbabwe         14                             Alfred Makwarimba
# 46555     Zimbabwe         14                             Blessing Chebundo
# 46556     Zimbabwe         14                             Munyaradzi Gwisai
# 46557     Zimbabwe         14                         Alfred Nikita Mangena
# 46558     Zimbabwe         14                             Joseph Chinotimba
# 46559     Zimbabwe         14                              Simon Khaya-Moyo
# 46560     Zimbabwe         14                              Lovemore Matombo
# 46561     Zimbabwe         14                                  Ronald Penza
# 46562     Zimbabwe         14                              Maurice Nyagumbo
# 46563     Zimbabwe         14  List of Presidents of the Senate of Zimbabwe
# 46564     Zimbabwe         14                               Paurine Mpariwa
# 46565     Zimbabwe         14                                  Jevan Maseko
# 46566     eSwatini        1.4                                             0
#
#             rev_id prediction
# 0      789039267.0       Stub
# 1      802029007.0      Start
# 2      694519009.0      Start
# 3      786203824.0      Start
# 4      721094337.0       Stub
# 5      805063877.0       Stub
# 6      798644673.0       Stub
# 7      803018106.0       Stub
# 8      755193428.0       Stub
# 9      789818648.0      Start
# 10     805967589.0         GA
# 11     723736482.0       Stub
# 12     805775169.0      Start
# 13     799618550.0      Start
# 14     704938340.0      Start
# 15     789818730.0      Start
# 16     779084312.0          C
# 17     723481980.0       Stub
# 18     752026068.0       Stub
# 19     706112927.0       Stub
# 20     802286319.0      Start
# 21     806499548.0          C
# 22     794028379.0      Start
# 23     800555876.0      Start
# 24     796975361.0      Start
# 25     806496321.0          C
# 26     788882411.0      Start
# 27     745190115.0       Stub
# 28     795278213.0       Stub
# 29     799215547.0         FA
# ...            ...        ...
# 46537  784668448.0       Stub
# 46538  804811059.0      Start
# 46539  795247525.0       Stub
# 46540  788777043.0       Stub
# 46541  738810400.0       Stub
# 46542  669981316.0       Stub
# 46543  715867004.0       Stub
# 46544  807442408.0      Start
# 46545  802259324.0      Start
# 46546  803579259.0      Start
# 46547  789965571.0      Start
# 46548  783419906.0      Start
# 46549  776840034.0       Stub
# 46550  720008799.0       Stub
# 46551  797932659.0          C
# 46552  783637102.0          C
# 46553  716669163.0       Stub
# 46554  801370822.0       Stub
# 46555  791690130.0      Start
# 46556  755337199.0      Start
# 46557  712004487.0       Stub
# 46558  777482252.0          C
# 46559  730764918.0       Stub
# 46560  711958194.0       Stub
# 46561  789948565.0       Stub
# 46562  764826793.0      Start
# 46563  791068367.0       Stub
# 46564  757616437.0       Stub
# 46565  736911246.0       Stub
# 46566          0.0          0
#
# [46567 rows x 5 columns]

# %%
# Identify countries which do not have a full matching set of data and save in a separate csv
rejects = allData[(allData[['population','page']] == 0).any(axis=1)]
rejects.to_csv('wp_wpds_countries-no_match.csv')

# Create clean data set which has filtered out any rows with missing values
desired = allData[~(allData[['population','page']] == 0).any(axis=1)]
desired.to_csv('wp_wpds_politicians_by_country.csv')

# %%
desired
# Out:
#            country population  \
# 16     Afghanistan       36.5
# 17     Afghanistan       36.5
# 18     Afghanistan       36.5
# 19     Afghanistan       36.5
# 20     Afghanistan       36.5
# 21     Afghanistan       36.5
# 22     Afghanistan       36.5
# 23     Afghanistan       36.5
# 24     Afghanistan       36.5
# 25     Afghanistan       36.5
# 26     Afghanistan       36.5
# 27     Afghanistan       36.5
# 28     Afghanistan       36.5
# 29     Afghanistan       36.5
# 30     Afghanistan       36.5
# 31     Afghanistan       36.5
# 32     Afghanistan       36.5
# 33     Afghanistan       36.5
# 34     Afghanistan       36.5
# 35     Afghanistan       36.5
# 36     Afghanistan       36.5
# 37     Afghanistan       36.5
# 38     Afghanistan       36.5
# 39     Afghanistan       36.5
# 40     Afghanistan       36.5
# 41     Afghanistan       36.5
# 42     Afghanistan       36.5
# 43     Afghanistan       36.5
# 44     Afghanistan       36.5
# 45     Afghanistan       36.5
# ...            ...        ...
# 46536     Zimbabwe         14
# 46537     Zimbabwe         14
# 46538     Zimbabwe         14
# 46539     Zimbabwe         14
# 46540     Zimbabwe         14
# 46541     Zimbabwe         14
# 46542     Zimbabwe         14
# 46543     Zimbabwe         14
# 46544     Zimbabwe         14
# 46545     Zimbabwe         14
# 46546     Zimbabwe         14
# 46547     Zimbabwe         14
# 46548     Zimbabwe         14
# 46549     Zimbabwe         14
# 46550     Zimbabwe         14
# 46551     Zimbabwe         14
# 46552     Zimbabwe         14
# 46553     Zimbabwe         14
# 46554     Zimbabwe         14
# 46555     Zimbabwe         14
# 46556     Zimbabwe         14
# 46557     Zimbabwe         14
# 46558     Zimbabwe         14
# 46559     Zimbabwe         14
# 46560     Zimbabwe         14
# 46561     Zimbabwe         14
# 46562     Zimbabwe         14
# 46563     Zimbabwe         14
# 46564     Zimbabwe         14
# 46565     Zimbabwe         14
#
#                                                     page       rev_id  \
# 16                                      Nur ul-Haq Ulumi  779084312.0
# 17                                   Al-Haj Suliman Yari  723481980.0
# 18                                 Ghulam Qawis Abubaker  752026068.0
# 19                                 Mohammad Fahim Dashty  706112927.0
# 20                                         Seema Jowenda  802286319.0
# 21              Dost Mohammad Khan (Emir of Afghanistan)  806499548.0
# 22                                Hashmat Ghani Ahmadzai  794028379.0
# 23                                         Humayun Azizi  800555876.0
# 24                                     Abdul Ahad Karzai  796975361.0
# 25                                     Abdullah Abdullah  806496321.0
# 26                              Amir Muhammad Akhundzada  788882411.0
# 27                                         Mohammad Aman  745190115.0
# 28                                Haji Mohammad Chamkani  795278213.0
# 29                                        Amrullah Saleh  799215547.0
# 30                                    Mohammad Nabi Safi  715926834.0
# 31                                     Fazal Haq Mujahid  782845346.0
# 32                                     Shah Mahmood Safi  715926905.0
# 33                                               Jan Baz  766272734.0
# 34                                     Hasan Ali Sultani  718362588.0
# 35                                      Ali Shah Durrani  795268854.0
# 36                               Sayed Mohammad Gulabzoy  756609530.0
# 37                                 Abdul Baqi Turkistani  718250607.0
# 38                                    Zarar Ahmad Osmani  795280683.0
# 39     List of candidates in the Afghan presidential ...  795279646.0
# 40                                 Mohammad Nasim Faqiri  766309040.0
# 41                                     Jan Mohammad Khan  794478106.0
# 42                                   Shah Shujah Durrani  796493730.0
# 43                                     Abdur Rahman Khan  803792380.0
# 44                                Mohammad Ghous Bashiri  723709911.0
# 45                                      Anahita Ratebzad  802551672.0
# ...                                                  ...          ...
# 46536                                       Andrew Langa  789094827.0
# 46537                                      Michael Bimha  784668448.0
# 46538                                       Kembo Mohadi  804811059.0
# 46539                                    Walter Chidakwa  795247525.0
# 46540                                  Ambrose Mutinhiri  788777043.0
# 46541                                      Sesel Zvidzai  738810400.0
# 46542                                    Fletcher Dulini  669981316.0
# 46543                                 Henry Dzinotyiweyi  715867004.0
# 46544                                  Guy Clutton-Brock  807442408.0
# 46545                                     Edna Madzongwe  802259324.0
# 46546                                  Promise Mkwananzi  803579259.0
# 46547                                        Joseph Made  789965571.0
# 46548                                     Margaret Dongo  783419906.0
# 46549                                        Joel Gabuza  776840034.0
# 46550                                Misheck Kagurabadza  720008799.0
# 46551                                   Arthur Mutambara  797932659.0
# 46552                                      Sekai Holland  783637102.0
# 46553                                    Rekayi Tangwena  716669163.0
# 46554                                  Alfred Makwarimba  801370822.0
# 46555                                  Blessing Chebundo  791690130.0
# 46556                                  Munyaradzi Gwisai  755337199.0
# 46557                              Alfred Nikita Mangena  712004487.0
# 46558                                  Joseph Chinotimba  777482252.0
# 46559                                   Simon Khaya-Moyo  730764918.0
# 46560                                   Lovemore Matombo  711958194.0
# 46561                                       Ronald Penza  789948565.0
# 46562                                   Maurice Nyagumbo  764826793.0
# 46563       List of Presidents of the Senate of Zimbabwe  791068367.0
# 46564                                    Paurine Mpariwa  757616437.0
# 46565                                       Jevan Maseko  736911246.0
#
#       prediction
# 16             C
# 17          Stub
# 18          Stub
# 19          Stub
# 20         Start
# 21             C
# 22         Start
# 23         Start
# 24         Start
# 25             C
# 26         Start
# 27          Stub
# 28          Stub
# 29            FA
# 30          Stub
# 31             C
# 32          Stub
# 33          Stub
# 34          Stub
# 35          Stub
# 36         Start
# 37          Stub
# 38         Start
# 39             C
# 40         Start
# 41            GA
# 42            GA
# 43            GA
# 44          Stub
# 45             C
# ...          ...
# 46536       Stub
# 46537       Stub
# 46538      Start
# 46539       Stub
# 46540       Stub
# 46541       Stub
# 46542       Stub
# 46543       Stub
# 46544      Start
# 46545      Start
# 46546      Start
# 46547      Start
# 46548      Start
# 46549       Stub
# 46550       Stub
# 46551          C
# 46552          C
# 46553       Stub
# 46554       Stub
# 46555      Start
# 46556      Start
# 46557       Stub
# 46558          C
# 46559       Stub
# 46560       Stub
# 46561       Stub
# 46562      Start
# 46563       Stub
# 46564       Stub
# 46565       Stub
#
# [44464 rows x 5 columns]

# %% [markdown]
# ## III. Data Analysis
# 1. Top 10 countries by coverage: 10 highest-ranked countries in terms of number of politician articles as a proportion of country population
# 2. Bottom 10 countries by coverage: 10 lowest-ranked countries in terms of number of politician articles as a proportion of country population
# 3. Top 10 countries by relative quality: 10 highest-ranked countries in terms of the relative proportion of politician articles that are of GA and FA-quality
# 4. Bottom 10 countries by relative quality: 10 lowest-ranked countries in terms of the relative proportion of politician articles that are of GA and FA-quality
# 5. Geographic regions by coverage: Ranking of geographic regions (in descending order) in terms of the total count of politician articles from countries in each region as a proportion of total regional population
# 6. Geographic regions by coverage: Ranking of geographic regions (in descending order) in terms of the relative proportion of politician articles from countries in each region that are of GA and FA-quality

# %% [markdown]
# ## VI. Conclusion
